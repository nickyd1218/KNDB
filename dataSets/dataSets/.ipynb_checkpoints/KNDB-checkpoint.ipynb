# %% [markdown]
# # Creating and Cleaning Data Set

# %%
import pandas as pd
import csv

mvpdataload= "MVPlayerOTY_fixed.xlsx"
seasonstatload = "Seasons_Stats_fixed.csv"

sdata = pd.read_csv(seasonstatload)
mdata = pd.read_excel(mvpdataload)

# %%
sdata.head()
# Out:
#      Year           Player Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong   F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   G  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   F  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels   F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels   F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 50 columns]

# %%
mdata.head()
# Out:
#    Year             Player Award
# 0  2017       James Harden   MVP
# 1  2016  Russell Westbrook   MVP
# 2  2015      Stephen Curry   MVP
# 3  2014      Stephen Curry   MVP
# 4  2013       Kevin Durant   MVP

# %%
kndb = pd.merge(sdata, mdata, how='left', on=["Year","Player"])

# %%
kndb
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0    Curly Armstrong   F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0       Cliff Barker   G  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0      Leo Barnhorst   F  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0         Ed Bartels   F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0         Ed Bartels   F  24.0  DNN  13.0   NaN     NaN   NaN
# 5      1950.0         Ed Bartels   F  24.0  NYK   2.0   NaN     NaN   NaN
# 6      1950.0        Ralph Beard   G  22.0  INO  60.0   NaN     NaN   NaN
# 7      1950.0         Gene Berce   F  23.0  TRI   3.0   NaN     NaN   NaN
# 8      1950.0      Charlie Black   C  28.0  TOT  65.0   NaN     NaN   NaN
# 9      1950.0      Charlie Black   C  28.0  FTW  36.0   NaN     NaN   NaN
# 10     1950.0      Charlie Black   C  28.0  AND  29.0   NaN     NaN   NaN
# 11     1950.0        Nelson Bobb   G  25.0  PHW  57.0   NaN     NaN   NaN
# 12     1950.0    Jake Bornheimer   C  22.0  PHW  60.0   NaN     NaN   NaN
# 13     1950.0       Vince Boryla   F  22.0  NYK  59.0   NaN     NaN   NaN
# 14     1950.0          Don Boven   F  24.0  WAT  62.0   NaN     NaN   NaN
# 15     1950.0      Harry Boykoff   C  27.0  WAT  61.0   NaN     NaN   NaN
# 16     1950.0        Joe Bradley   G  21.0  CHS  46.0   NaN     NaN   NaN
# 17     1950.0        Bob Brannum   F  24.0  SHE  59.0   NaN     NaN   NaN
# 18     1950.0         Carl Braun   F  22.0  NYK  67.0   NaN     NaN   NaN
# 19     1950.0      Frankie Brian   G  26.0  AND  64.0   NaN     NaN   NaN
# 20     1950.0   Price Brookfield   F  29.0  ROC   7.0   NaN     NaN   NaN
# 21     1950.0          Bob Brown   F  26.0  DNN  62.0   NaN     NaN   NaN
# 22     1950.0         Jim Browne   C  20.0  DNN  31.0   NaN     NaN   NaN
# 23     1950.0         Walt Budko   F  24.0  BLB  66.0   NaN     NaN   NaN
# 24     1950.0     Jack Burmaster   G  23.0  SHE  61.0   NaN     NaN   NaN
# 25     1950.0       Tommy Byrnes   F  26.0  BLB  53.0   NaN     NaN   NaN
# 26     1950.0       Bill Calhoun   G  22.0  ROC  62.0   NaN     NaN   NaN
# 27     1950.0        Don Carlson   F  30.0  MNL  57.0   NaN     NaN   NaN
# 28     1950.0      Bob Carpenter   C  32.0  FTW  66.0   NaN     NaN   NaN
# 29     1950.0        Jake Carter   C  25.0  TOT  24.0   NaN     NaN   NaN
# ...       ...                ...  ..   ...  ...   ...   ...     ...   ...
# 24661  2017.0     Deron Williams   G  32.0  TOT  64.0  44.0  1657.0  14.0
# 24662  2017.0     Deron Williams   G  32.0  DAL  40.0  40.0  1171.0  15.0
# 24663  2017.0     Deron Williams   G  32.0  CLE  24.0   4.0   486.0  11.4
# 24664  2017.0   Derrick Williams   F  25.0  TOT  50.0  11.0   804.0  10.6
# 24665  2017.0   Derrick Williams   F  25.0  MIA  25.0  11.0   377.0  10.1
# 24666  2017.0   Derrick Williams   F  25.0  CLE  25.0   0.0   427.0  11.1
# 24667  2017.0       Lou Williams   G  30.0  TOT  81.0   1.0  1994.0  21.4
# 24668  2017.0       Lou Williams   G  30.0  LAL  58.0   1.0  1403.0  23.9
# 24669  2017.0       Lou Williams   G  30.0  HOU  23.0   0.0   591.0  15.4
# 24670  2017.0    Marvin Williams   F  30.0  CHO  76.0  76.0  2295.0  13.7
# 24671  2017.0    Reggie Williams   F  30.0  NOP   6.0   0.0    79.0  11.7
# 24672  2017.0      Troy Williams   F  22.0  TOT  30.0  16.0   557.0   8.9
# 24673  2017.0      Troy Williams   F  22.0  MEM  24.0  13.0   418.0   7.6
# 24674  2017.0      Troy Williams   F  22.0  HOU   6.0   3.0   139.0  12.8
# 24675  2017.0       Kyle Wiltjer   F  24.0  HOU  14.0   0.0    44.0   6.7
# 24676  2017.0    Justise Winslow   F  20.0  MIA  18.0  15.0   625.0   8.2
# 24677  2017.0        Jeff Withey   C  26.0  UTA  51.0   1.0   432.0  18.8
# 24678  2017.0     Christian Wood   F  21.0  CHO  13.0   0.0   107.0  15.1
# 24679  2017.0        Metta World   F  37.0  LAL  25.0   2.0   160.0   6.2
# 24680  2017.0     Brandan Wright   F  29.0  MEM  28.0   5.0   447.0  18.5
# 24681  2017.0       Delon Wright   G  24.0  TOR  27.0   0.0   446.0  15.0
# 24682  2017.0        James Young   G  21.0  BOS  29.0   0.0   220.0  10.0
# 24683  2017.0          Joe Young   G  24.0  IND  33.0   0.0   135.0  11.4
# 24684  2017.0         Nick Young   G  31.0  LAL  60.0  60.0  1556.0  14.1
# 24685  2017.0     Thaddeus Young   F  28.0  IND  74.0  74.0  2237.0  14.9
# 24686  2017.0        Cody Zeller   F  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser   F  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...      ORB    DRB    TRB    AST    STL   BLK    TOV     PF  \
# 0      0.368  ...      NaN    NaN    NaN  176.0    NaN   NaN    NaN  217.0
# 1      0.435  ...      NaN    NaN    NaN  109.0    NaN   NaN    NaN   99.0
# 2      0.394  ...      NaN    NaN    NaN  140.0    NaN   NaN    NaN  192.0
# 3      0.312  ...      NaN    NaN    NaN   20.0    NaN   NaN    NaN   29.0
# 4      0.308  ...      NaN    NaN    NaN   20.0    NaN   NaN    NaN   27.0
# 5      0.376  ...      NaN    NaN    NaN    0.0    NaN   NaN    NaN    2.0
# 6      0.422  ...      NaN    NaN    NaN  233.0    NaN   NaN    NaN  132.0
# 7      0.275  ...      NaN    NaN    NaN    2.0    NaN   NaN    NaN    6.0
# 8      0.346  ...      NaN    NaN    NaN  163.0    NaN   NaN    NaN  273.0
# 9      0.362  ...      NaN    NaN    NaN   75.0    NaN   NaN    NaN  140.0
# 10     0.326  ...      NaN    NaN    NaN   88.0    NaN   NaN    NaN  133.0
# 11     0.396  ...      NaN    NaN    NaN   46.0    NaN   NaN    NaN   97.0
# 12     0.356  ...      NaN    NaN    NaN   40.0    NaN   NaN    NaN  111.0
# 13     0.426  ...      NaN    NaN    NaN   95.0    NaN   NaN    NaN  203.0
# 14     0.461  ...      NaN    NaN    NaN  137.0    NaN   NaN    NaN  255.0
# 15     0.479  ...      NaN    NaN    NaN  149.0    NaN   NaN    NaN  229.0
# 16     0.289  ...      NaN    NaN    NaN   36.0    NaN   NaN    NaN   51.0
# 17     0.408  ...      NaN    NaN    NaN  205.0    NaN   NaN    NaN  279.0
# 18     0.434  ...      NaN    NaN    NaN  247.0    NaN   NaN    NaN  188.0
# 19     0.415  ...      NaN    NaN    NaN  189.0    NaN   NaN    NaN  192.0
# 20     0.592  ...      NaN    NaN    NaN    1.0    NaN   NaN    NaN    7.0
# 21     0.414  ...      NaN    NaN    NaN  101.0    NaN   NaN    NaN  269.0
# 22     0.392  ...      NaN    NaN    NaN    8.0    NaN   NaN    NaN   16.0
# 23     0.388  ...      NaN    NaN    NaN  146.0    NaN   NaN    NaN  259.0
# 24     0.378  ...      NaN    NaN    NaN  179.0    NaN   NaN    NaN  237.0
# 25     0.362  ...      NaN    NaN    NaN   88.0    NaN   NaN    NaN   76.0
# 26     0.439  ...      NaN    NaN    NaN  115.0    NaN   NaN    NaN  100.0
# 27     0.402  ...      NaN    NaN    NaN   76.0    NaN   NaN    NaN  126.0
# 28     0.421  ...      NaN    NaN    NaN   92.0    NaN   NaN    NaN  168.0
# 29     0.417  ...      NaN    NaN    NaN   24.0    NaN   NaN    NaN   59.0
# ...      ...  ...      ...    ...    ...    ...    ...   ...    ...    ...
# 24661  0.541  ...     14.0  133.0  147.0  360.0   31.0   8.0  138.0  138.0
# 24662  0.533  ...     13.0   89.0  102.0  274.0   25.0   2.0   98.0   96.0
# 24663  0.566  ...      1.0   44.0   45.0   86.0    6.0   6.0   40.0   42.0
# 24664  0.537  ...     19.0  111.0  130.0   28.0   14.0   7.0   28.0   60.0
# 24665  0.465  ...     16.0   57.0   73.0   14.0    9.0   5.0   14.0   33.0
# 24666  0.628  ...      3.0   54.0   57.0   14.0    5.0   2.0   14.0   27.0
# 24667  0.593  ...     26.0  176.0  202.0  239.0   80.0  19.0  160.0   92.0
# 24668  0.609  ...     14.0  118.0  132.0  183.0   65.0  10.0  120.0   67.0
# 24669  0.547  ...     12.0   58.0   70.0   56.0   15.0   9.0   40.0   25.0
# 24670  0.551  ...     89.0  409.0  498.0  106.0   58.0  53.0   60.0  134.0
# 24671  0.518  ...      2.0    4.0    6.0    4.0    3.0   0.0    0.0    2.0
# 24672  0.511  ...     15.0   54.0   69.0   25.0   27.0  10.0   33.0   60.0
# 24673  0.474  ...      6.0   39.0   45.0   19.0   24.0   9.0   27.0   42.0
# 24674  0.616  ...      9.0   15.0   24.0    6.0    3.0   1.0    6.0   18.0
# 24675  0.437  ...      4.0    6.0   10.0    2.0    3.0   1.0    5.0    4.0
# 24676  0.399  ...     23.0   71.0   94.0   66.0   27.0   6.0   33.0   52.0
# 24677  0.588  ...     52.0   69.0  121.0    7.0   16.0  32.0   14.0   52.0
# 24678  0.591  ...     14.0   15.0   29.0    2.0    3.0   6.0    7.0   11.0
# 24679  0.380  ...      5.0   15.0   20.0   11.0    9.0   2.0    7.0   18.0
# 24680  0.628  ...     31.0   47.0   78.0   15.0   11.0  20.0   10.0   42.0
# 24681  0.535  ...     16.0   32.0   48.0   57.0   27.0  11.0   25.0   31.0
# 24682  0.549  ...      6.0   20.0   26.0    4.0   10.0   2.0    4.0   15.0
# 24683  0.433  ...      1.0   16.0   17.0   15.0    4.0   0.0    5.0    5.0
# 24684  0.588  ...     25.0  112.0  137.0   58.0   37.0  14.0   36.0  137.0
# 24685  0.562  ...    131.0  318.0  449.0  122.0  114.0  30.0   96.0  135.0
# 24686  0.604  ...    135.0  270.0  405.0   99.0   62.0  58.0   65.0  189.0
# 24687  0.508  ...     43.0   81.0  124.0   42.0    7.0  21.0   20.0   61.0
# 24688  0.346  ...     11.0   24.0   35.0    4.0    2.0   5.0    3.0   17.0
# 24689  0.503  ...     15.0  110.0  125.0   36.0   15.0  16.0   40.0   78.0
# 24690  0.547  ...     41.0  118.0  159.0   30.0   14.0  33.0   30.0   66.0
#
#           PTS  Award
# 0       458.0    NaN
# 1       279.0    NaN
# 2       438.0    NaN
# 3        63.0    NaN
# 4        59.0    NaN
# 5         4.0    NaN
# 6       895.0    NaN
# 7        10.0    NaN
# 8       661.0    NaN
# 9       382.0    NaN
# 10      279.0    NaN
# 11      242.0    NaN
# 12      254.0    NaN
# 13      612.0    NaN
# 14      656.0    NaN
# 15      779.0    NaN
# 16       87.0    NaN
# 17      713.0    NaN
# 18     1031.0    NaN
# 19     1138.0    NaN
# 20       34.0    NaN
# 21      724.0    NaN
# 22       47.0    NaN
# 23      595.0    NaN
# 24      598.0    NaN
# 25      327.0    NaN
# 26      560.0    NaN
# 27      267.0    NaN
# 28      614.0    NaN
# 29       82.0    NaN
# ...       ...    ...
# 24661   701.0    NaN
# 24662   522.0    NaN
# 24663   179.0    NaN
# 24664   304.0    NaN
# 24665   148.0    NaN
# 24666   156.0    NaN
# 24667  1421.0    NaN
# 24668  1078.0    NaN
# 24669   343.0    NaN
# 24670   849.0    NaN
# 24671    27.0    NaN
# 24672   185.0    NaN
# 24673   127.0    NaN
# 24674    58.0    NaN
# 24675    13.0    NaN
# 24676   196.0    NaN
# 24677   146.0    NaN
# 24678    35.0    NaN
# 24679    57.0    NaN
# 24680   189.0    NaN
# 24681   150.0    NaN
# 24682    68.0    NaN
# 24683    68.0    NaN
# 24684   791.0    NaN
# 24685   814.0    NaN
# 24686   639.0    NaN
# 24687   178.0    NaN
# 24688    23.0    NaN
# 24689   240.0    NaN
# 24690   284.0    NaN
#
# [24691 rows x 51 columns]

# %%
kndb = kndb[kndb.Year >= 1980]

# %%
kndb_test = kndb[kndb.Year != 2017]
kndb_test = kndb_test.drop(columns = ['Player','Tm'])

# %%
kndb_test.dtypes
# Out:
# Year     float64
# Pos       object
# Age      float64
# G        float64
# GS       float64
# MP       float64
# PER      float64
# TS%      float64
# 3PAr     float64
# FTr      float64
# ORB%     float64
# DRB%     float64
# TRB%     float64
# AST%     float64
# STL%     float64
# BLK%     float64
# TOV%     float64
# USG%     float64
# OWS      float64
# DWS      float64
# WS       float64
# WS/48    float64
# OBPM     float64
# DBPM     float64
# BPM      float64
# VORP     float64
# FG       float64
# FGA      float64
# FG%      float64
# 3P       float64
# 3PA      float64
# 3P%      float64
# 2P       float64
# 2PA      float64
# 2P%      float64
# eFG%     float64
# FT       float64
# FTA      float64
# FT%      float64
# ORB      float64
# DRB      float64
# TRB      float64
# AST      float64
# STL      float64
# BLK      float64
# TOV      float64
# PF       float64
# PTS      float64
# Award     object
# dtype: object

# %%
kndb_test.head()
# Out:
#         Year Pos   Age     G    GS      MP   PER    TS%   3PAr    FTr  ...    \
# 5727  1980.0   C  32.0  82.0   NaN  3143.0  25.3  0.639  0.001  0.344  ...
# 5728  1980.0   F  25.0  67.0   NaN  1222.0  11.0  0.511  0.003  0.258  ...
# 5729  1980.0   C  25.0  75.0   NaN  2168.0  19.2  0.571  0.002  0.270  ...
# 5730  1980.0   G  31.0  80.0  80.0  2864.0  15.3  0.574  0.023  0.548  ...
# 5731  1980.0   C  31.0  26.0   NaN   560.0   7.4  0.524  0.000  0.833  ...
#
#         ORB    DRB    TRB    AST    STL    BLK    TOV     PF     PTS  Award
# 5727  190.0  696.0  886.0  371.0   81.0  280.0  297.0  216.0  2034.0    NaN
# 5728   62.0  129.0  191.0   87.0   35.0   12.0   39.0  118.0   362.0    NaN
# 5729  158.0  451.0  609.0  322.0  108.0   55.0  218.0  237.0  1118.0    NaN
# 5730   59.0  138.0  197.0  671.0  106.0   10.0  242.0  218.0  1131.0    NaN
# 5731   29.0   86.0  115.0   40.0   12.0   15.0   27.0   66.0    86.0    NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# # Linear Model Logistic Regression Machine Learning

# %%
X = kndb_test.drop("Award", axis=1)
y = kndb_test["Award"]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X = LabelEncoder()
kndb_test[:, 2] = labelencoder_X.fit_transform(X[:,2])
onehotencoder = OneHotEncoder(categorical_features = [3])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-8b7575297caf> in <module>()
#       1 from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#       2 labelencoder_X = LabelEncoder()
# ----> 3 kndb_test[:, 2] = labelencoder_X.fit_transform(X[:,2])
#       4 onehotencoder = OneHotEncoder(categorical_features = [3])
#       5 X = onehotencoder.fit_transform(X).toarray()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2482         """Return the cached item, item represents a label indexer."""
#    2483         cache = self._item_cache
# -> 2484         res = cache.get(item)
#    2485         if res is None:
#    2486             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-a668c1bc75d7> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2054                      random_state=random_state)
#    2055
# -> 2056         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2057
#    2058     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1202         """
#    1203         X, y, groups = indexable(X, y, groups)
# -> 1204         for train, test in self._iter_indices(X, y, groups):
#    1205             yield train, test
#    1206
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _iter_indices(self, X, y, groups)
#    1539             y = np.array([' '.join(row.astype('str')) for row in y])
#    1540
# -> 1541         classes, y_indices = np.unique(y, return_inverse=True)
#    1542         n_classes = classes.shape[0]
#    1543
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     278
#     279     if optional_indices:
# --> 280         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     281         aux = ar[perm]
#     282     else:
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-f44724590846> in <module>()
# ----> 1 classifier.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
kndb_predict = kndb[kndb.Year = 2017]
predictions = classifier.predict(kndb_predict)
# Out:
#   File "<ipython-input-65-990ee4ef9b22>", line 1
#     kndb_predict = kndb[kndb.Year = 2017]
#                                   ^
# SyntaxError: invalid syntax
