# %% [markdown]
# # Creating and Cleaning Data Set

# %%
import pandas as pd
import csv

mvpdataload= "MVPlayerOTY.xlsx"
seasonstatload = "Seasons_Stats.csv"

sdata = pd.read_csv(seasonstatload)
mdata = pd.read_excel(mvpdataload)

# %%
sdata.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
mdata.head()
# Out:
#    Year             Player  Age   Tm   G    MP   PTS   TRB   AST  STL  BLK  \
# 0  2017       James Harden   28  HOU  72  35.4  30.4   5.4   8.8  1.8  0.7
# 1  2016  Russell Westbrook   28  OKC  81  34.6  31.6  10.7  10.4  1.6  0.4
# 2  2015      Stephen Curry   27  GSW  79  34.2  30.1   5.4   6.7  2.1  0.2
# 3  2014      Stephen Curry   26  GSW  80  32.7  23.8   4.3   7.7  2.0  0.2
# 4  2013       Kevin Durant   25  OKC  81  38.5  32.0   7.4   5.5  1.3  0.7
#
#      FG%    3P%    FT% Award
# 0  0.449  0.367  0.858   MVP
# 1  0.425  0.343  0.845   MVP
# 2  0.504  0.454  0.908   MVP
# 3  0.487  0.443  0.914   MVP
# 4  0.503  0.391  0.873   MVP

# %%
kndb = pd.merge(sdata, mdata, how='left', on=["Year","Player"])

# %%
kndb
# Out:
#        Unnamed: 0    Year             Player  Pos  Age_x Tm_x   G_x    GS  \
# 0               0  1950.0    Curly Armstrong  G-F   31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG   29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF   25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F   24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F   24.0  DNN  13.0   NaN
# 5               5  1950.0         Ed Bartels    F   24.0  NYK   2.0   NaN
# 6               6  1950.0        Ralph Beard    G   22.0  INO  60.0   NaN
# 7               7  1950.0         Gene Berce  G-F   23.0  TRI   3.0   NaN
# 8               8  1950.0      Charlie Black  F-C   28.0  TOT  65.0   NaN
# 9               9  1950.0      Charlie Black  F-C   28.0  FTW  36.0   NaN
# 10             10  1950.0      Charlie Black  F-C   28.0  AND  29.0   NaN
# 11             11  1950.0        Nelson Bobb   PG   25.0  PHW  57.0   NaN
# ...

# %%
kndb = kndb[kndb.Year >= 1980]

# %%
kndb_test = kndb[kndb.Year != 2017]
kndb_test
# Out:
#        Unnamed: 0    Year                Player    Pos  Age_x Tm_x   G_x  \
# 5727         5727  1980.0  Kareem Abdul-Jabbar*      C   32.0  LAL  82.0
# 5728         5728  1980.0         Tom Abernethy     PF   25.0  GSW  67.0
# 5729         5729  1980.0           Alvan Adams      C   25.0  PHO  75.0
# 5730         5730  1980.0       Tiny Archibald*     PG   31.0  BOS  80.0
# 5731         5731  1980.0         Dennis Awtrey      C   31.0  CHI  26.0
# 5732         5732  1980.0            Gus Bailey     SG   28.0  WSB  20.0
# 5733         5733  1980.0          James Bailey     PF   22.0  SEA  67.0
# 5734         5734  1980.0          Greg Ballard     SF   25.0  WSB  82.0
# 5735         5735  1980.0           Mike Bantom     SF   28.0  IND  77.0
# 5736         5736  1980.0         Marvin Barnes     PF   27.0  SDC  20.0
# 5737         5737  1980.0           Rick Barry*     SF   35.0  HOU  72.0
# 5738         5738  1980.0           Tim Bassett     PF   28.0  TOT  12.0
# ...

# %%
kndb_test.dtypes
# Out:
# Unnamed: 0      int64
# Year          float64
# Player         object
# Pos            object
# Age_x         float64
# Tm_x           object
# G_x           float64
# GS            float64
# MP_x          float64
# PER           float64
# TS%           float64
# 3PAr          float64
# FTr           float64
# ORB%          float64
# DRB%          float64
# TRB%          float64
# AST%          float64
# STL%          float64
# BLK%          float64
# TOV%          float64
# USG%          float64
# blanl         float64
# OWS           float64
# DWS           float64
# WS            float64
# WS/48         float64
# blank2        float64
# OBPM          float64
# DBPM          float64
# BPM           float64
#                ...
# 3P%_x         float64
# 2P            float64
# 2PA           float64
# 2P%           float64
# eFG%          float64
# FT            float64
# FTA           float64
# FT%_x         float64
# ORB           float64
# DRB           float64
# ...

# %% [markdown]
# # Linear Model Logistic Regression Machine Learning

# %%
X = kndb.drop("Award", axis=1)
y = kndb["Award"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-a668c1bc75d7> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2054                      random_state=random_state)
#    2055
# -> 2056         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2057
#    2058     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1202         """
#    1203         X, y, groups = indexable(X, y, groups)
# -> 1204         for train, test in self._iter_indices(X, y, groups):
#    1205             yield train, test
#    1206
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-f44724590846> in <module>()
# ----> 1 classifier.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
kndb_predict = kndb[kndb.Year = 2017]
predictions = classifier.predict(kndb_predict)
# Out:
#   File "<ipython-input-65-990ee4ef9b22>", line 1
#     kndb_predict = kndb[kndb.Year = 2017]
#                                   ^
# SyntaxError: invalid syntax
